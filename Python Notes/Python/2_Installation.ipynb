# %% [markdown]
# # Install Python

# %% [markdown]
# ## Install Python on Windows :

# %% [markdown]
# * First, [download the latest version of Python](https://www.python.org/downloads/) from the download page.
# * Second, double-click the installer file to launch the setup wizard.
# * In the setup window, you need to check the Add Python 3.8 to PATH and click Install Now to begin the installation.
#
# * after installation...
# * In the Command Prompt, type **python** command.

# %% [markdown]
# # Install Visual Code Studio Editior :

# %% [markdown]
# * First, [download the lasted version of VS Code](https://code.visualstudio.com/download) from the download page.
# * Second, click **Next** to **Next**.

# %% [markdown]
# # Install PyCharm Community Edition :

# %% [markdown]
# * First, [download the lasted version of PyCharm](https://www.jetbrains.com/pycharm/download/?section=windows) from the download page.
